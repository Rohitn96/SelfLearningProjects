# %%
## Aim - Checking the correlation between the various indicators in the Movie data to check the factors that influences the Gross Earnings.

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# Read the data

df = pd.read_csv(r'C:\Users\rohit\OneDrive\Desktop\PortfolioProjects\Movies\movies.csv')

# %%
# Lets look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# To check if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Fill missing values in numeric columns with the mean
numeric_cols = ['rating', 'score', 'votes', 'budget', 'gross', 'runtime']
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean(numeric_only=True))

# Fill missing values in string/categorical columns with a specific value
string_cols = ['released', 'writer', 'star', 'country', 'company']
df[string_cols] = df[string_cols].fillna('Unknown')

# Now, check for any remaining missing values
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Checking the data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing the data types

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

df['votes'] = df['votes'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Sorting the data

df.sort_values(by=['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3818                        Love, Honor and Obey          R  Comedy  2000
# 7625                            The Untold Story        NaN  Comedy  2019
# 7580                         Run with the Hunted  Not Rated   Crime  2019
# 2417                                    Madadayo        NaN   Drama  1993
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes         director  \
# ...

# %%
# Drop any duplicates

df.drop_duplicates().head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Scatter Plot with Budget vs Gross Earnings

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot Budget vs Gross using Seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"},line_kws={"color":"green"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Correlation of Data
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097936  0.222810  0.265578  0.252042  0.120766
# score    0.097936  1.000000  0.409182  0.064541  0.182868  0.399329
# votes    0.222810  0.409182  1.000000  0.421007  0.628713  0.309166
# budget   0.265578  0.064541  0.421007  1.000000  0.711270  0.265287
# gross    0.252042  0.182868  0.628713  0.711270  1.000000  0.241335
# runtime  0.120766  0.399329  0.309166  0.265287  0.241335  1.000000

# %%
# The budget vs gross has the highest correlation

correlation_matrix = df.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot=True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released     score    votes  director  \
# 0     6587       6      6  1980      1705  8.400000   927000      2589
# 1     5573       6      1  1980      1492  5.800000    65000      2269
# 2     5142       4      0  1980      1771  8.700000  1200000      1111
# 3      286       4      4  1980      1492  7.700000   221000      1301
# 4     1027       6      4  1980      1543  7.300000   108000      1054
# ...    ...     ...    ...   ...       ...       ...      ...       ...
# 7663  3705      -1      6  2020      2964  3.100000       18      1500
# 7664  1678      -1      4  2020      1107  4.700000       36       774
# 7665  4717      -1      6  2020       193  5.700000       29      2061
# 7666  2843      -1      6  2020      2817  6.390411    88108      1184
# 7667  5394      -1     10  2020       391  5.700000        7      2165
#
#       writer  star  country    budget      gross  company     runtime
# ...

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3   286       4      4  1980      1492    7.7   221000      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000      1054     521
#
#    star  country    budget      gross  company  runtime
# 0  1047       54  19000000   46998772     2320    146.0
# 1   327       55   4500000   58853106      731    104.0
# 2  1745       55  18000000  538375067     1540    124.0
# 3  2246       55   3500000   83453539     1812     88.0
# 4   410       55   6000000   39846344     1777     98.0

# %%
# Correlation between all the columns


correlation_matrix = df_numerized.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot=True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year        0.011453
#          released   -0.010480
#                        ...
# runtime  country    -0.079188
#          budget      0.265287
#          gross       0.241335
#          company     0.031048
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre    budget    -0.310566
# budget   genre     -0.310566
# gross    genre     -0.230267
# genre    gross     -0.230267
#          votes     -0.145276
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross     votes       0.628713
# votes     gross       0.628713
# budget    gross       0.711270
# gross     budget      0.711270
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
## Interpretation

'Gross earnings and Votes have the highest correlation, that means the higher the votes, the more the film is expected to earn,The second highest factor is the budget.'
# Out:
# 'Gross earnings and Votes have the highest correlation, that means the higher the votes, the more the film is expected to earn,The second highest factor is the budget.'
